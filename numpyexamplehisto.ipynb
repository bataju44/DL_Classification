# %%
# Out:
# 2dhisto.py	       Canvas_1.pdf  pbs.txt.e1236485  rcSetup.sh
# 2dhisto.py~	       log.csv	     pbs.txt.o1236485  remove
# allmass.pdf	       log.csv~      pdf	       RootCoreBin
# backupFindParents.cxx  MySUSYHplus   pythonvinenv      tailm5
# Browse.py	       pbs.txt	     rcSetup.csh       test1

# %%
Files= "/cluster/home/bataju/20.4.28/log.csv"
# !head -8 "/cluster/home/bataju/20.4.28/log.csv"
# Out:
# 14,0,0.220709,0.220709,18259.6
# 22,0,-2.87019,-2.87019,0.281284
# 1000022,96688.1,-1.5969,-1.02054,57305.7
# -11,0.511,-0.816208,-0.816208,40469.1
# 1000022,96688.1,-0.633321,-0.252736,39425.2
# 11,0.511,0.892591,0.892591,18047.4
# 14,0,-3.17523,-3.17523,1955.28
# 22,0,0.698256,0.698256,1.20329

# %%
f = open("/cluster/home/bataju/20.4.28/log.csv",'r')

# %%
import pandas  as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /cluster/home/bataju/20.4.28/pythonvinenv/Venvs/MySUSYAnalysis/lib/python2.7/site-packages/pandas/_libs/__init__.py:4: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .tslib import iNaT, NaT, Timestamp, Timedelta, OutOfBoundsDatetime
# /cluster/home/bataju/20.4.28/pythonvinenv/Venvs/MySUSYAnalysis/lib/python2.7/site-packages/pandas/__init__.py:26: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (hashtable as _hashtable,
# /cluster/home/bataju/20.4.28/pythonvinenv/Venvs/MySUSYAnalysis/lib/python2.7/site-packages/pandas/core/dtypes/common.py:6: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import algos, lib
# ...

# %%
names = ["pdgId","mass","eta","rapidity","pT"]

# %%
df = pd.read_csv(Files,dtype='float64',names=names)

# %%
df
# Out:
#             pdgId       mass       eta  rapidity             pT
# 0            14.0      0.000  0.220709  0.220709   18259.600000
# 1            22.0      0.000 -2.870190 -2.870190       0.281284
# 2       1000022.0  96688.100 -1.596900 -1.020540   57305.700000
# 3           -11.0      0.511 -0.816208 -0.816208   40469.100000
# 4       1000022.0  96688.100 -0.633321 -0.252736   39425.200000
# 5            11.0      0.511  0.892591  0.892591   18047.400000
# 6            14.0      0.000 -3.175230 -3.175230    1955.280000
# 7            22.0      0.000  0.698256  0.698256       1.203290
# 8       1000022.0  96688.100  0.440152  0.289925   82015.000000
# 9            11.0      0.511  0.530405  0.530405   29700.400000
# 10      1000022.0  96688.100  0.027721  0.016083   68861.200000
# 11           22.0      0.000  1.660340  1.660340    1283.630000
# 12           12.0      0.000 -1.503370 -1.503370   29240.700000
# 13          -11.0      0.511  0.760257  0.760257   25505.200000
# ...

# %%
import numpy as np

# %%
for var in names[1:]:
    print var
    plt.figure()
    plt.hist(df[var],bins=100,histtype="step", color="red")
    plt.show()
# Out:
# mass
# eta
# rapidity
# pT

# %%
plt.figure()
plt.hist(df["eta"],bins="auto",histtype="step", color="red",label="eta",stacked=True)
plt.hist(df["rapidity"],bins="auto",histtype="step", color="blue", label="rapidity",stacked=True)
plt.legend(loc='upper right')
plt.title("eta vs rapidity")
plt.show()
